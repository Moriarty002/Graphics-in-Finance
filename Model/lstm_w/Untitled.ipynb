# %%
import Tools
import numpy as np
import pandas as pd

df_raw,df_index = Tools.checkCodeInDir('0050')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 1000)

display(df_index)

# df_index = df_index[['RSI_6','RSI_12','K','D','BIAS','WMR','EMA_12','EMA_26','MACD','psy_6','MTM_6','SAR_6','DM+(DMI)','DM-(DMI)','TR(DMI)','+DI(DMI)','-DI(DMI)','ADX(DMI)','Trend']].copy()


# # display(df_index)
# data = []

# for i in range(len(df_index)):
#     tmp = np.array(df_index.loc[i:i+29])
#     tmp = tmp.flatten()
#     print(tmp.shape)
#     data.append(tmp)

#     print(data)

# tmp = np.array(df_index.loc[0:29])
# tmp = tmp.flatten()
# print(tmp.shape)

# print(len(tmp))
# Out:
# found data [0050.json]at : ./../../stock_data
# found data [0050_index.json]at : ./../../stock_data_index
#              日期       成交股數        成交金額    開盤價    最高價    最低價    收盤價  漲跌價差  \
# 0      99/01/22   29477562  1612081382  55.20  55.20  54.35  54.40 -1.55
# 1      99/01/25   12845252   695785374  53.95  54.45  53.80  54.20 -0.20
# 2      99/01/26   26395774  1416284559  54.15  54.55  52.75  52.95 -1.25
# 3      99/01/27   14855839   787198926  52.95  53.30  52.70  52.90 -0.05
# 4      99/01/28   12622891   676089714  53.10  54.20  53.10  54.05  1.15
# 5      99/01/29   13799786   727944433  52.95  53.25  52.20  53.00 -1.05
# 6      99/02/01   19637117  1030361997  53.15  53.20  51.95  52.40 -0.60
# 7      99/02/02   11987878   625747966  52.95  52.95  51.60  51.85 -0.55
# 8      99/02/03   13598236   714184048  52.10  52.80  52.05  52.75  0.90
# 9      99/02/04    5940528   312541875  52.75  52.85  52.35  52.55 -0.20
# ...
